# %% [markdown]
# # 1. Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "svg"

# %% [markdown]
# # 2.Importing the dataset

# %%
# Storing Dataset
dataset=pd.read_csv('Zomato_Chennai_Listing_2020.csv')
dataset
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# ...

# %% [markdown]
# # 3.Getting Basic Information about the Dataset

# %%
# Number of rows and Columns
print("The Number of Row :", dataset.shape[0])
print("The Number of Columns :", dataset.shape[1])
# Out:
# The Number of Row : 12032
# The Number of Columns : 12

# %%
dataset.info
# Out:
# <bound method DataFrame.info of                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# ...

# %%
dataset.isnull().sum()
# Out:
# Zomato URL                  0
# Name of Restaurant          0
# Address                     0
# Location                    0
# Cuisine                     0
# Top Dishes                  0
# Price for 2                 0
# Dining Rating            5351
# Dining Rating Count       220
# Delivery Rating          5851
# Delivery Rating Count     220
# Features                    0
# dtype: int64

# %%
dataset.describe()
# Out:
#         Price for 2  Dining Rating  Delivery Rating
# count  12032.000000    6681.000000      6181.000000
# mean     397.611370       3.387756         3.805290
# std      332.045938       0.558181         0.374213
# min       40.000000       0.300000         0.300000
# 25%      200.000000       3.100000         3.600000
# 50%      300.000000       3.500000         3.900000
# 75%      450.000000       3.800000         4.000000
# max     5000.000000       4.900000         4.700000

# %% [markdown]
# #
#
#
# 4.Cleaning the Dataset

# %% [markdown]
# # a. Removing the redundant rows of data

# %%
# Performing Negation of the wrong dataset and then storing the correct data back in the raw_df DataFrame 
# This permamnently remove the wrong data from the original dataframe

# %%
# Dropping columns which are not required for further analysis
dataset.drop(['Zomato URL','Address'], axis = 1, inplace=True)
dataset
# Out:
#           Name of Restaurant         Location  \
# 0      Yaa Mohaideen Briyani       Pallavaram
# 1         Sukkubhai Biriyani          Alandur
# 2       SS Hyderabad Biryani      Kodambakkam
# 3                        KFC         Perambur
# 4              Tasty Kitchen         Perambur
# ...                      ...              ...
# 12027        CK's Sandwiches            Porur
# 12028        CK's Sandwiches         Kolathur
# 12029        CK's Sandwiches  Anna Nagar East
# 12030        CK's Sandwiches        Ramapuram
# 12031        CK's Sandwiches   Sholinganallur
#
#                                                  Cuisine  \
# 0                                            ['Biryani']
# 1      ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2      ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3      ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4      ['Chinese', ' Biryani', ' North Indian', ' Che...
# ...                                                  ...
# ...

# %% [markdown]
# # b. Removing the Null Records

# %%
# Checking for Null records
dataset.isnull().sum()
# Out:
# Name of Restaurant       0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %%
# Replacing the other null records with NA
dataset.fillna('NA', inplace=True)
dataset
# Out:
#           Name of Restaurant         Location  \
# 0      Yaa Mohaideen Briyani       Pallavaram
# 1         Sukkubhai Biriyani          Alandur
# 2       SS Hyderabad Biryani      Kodambakkam
# 3                        KFC         Perambur
# 4              Tasty Kitchen         Perambur
# ...                      ...              ...
# 12027        CK's Sandwiches            Porur
# 12028        CK's Sandwiches         Kolathur
# 12029        CK's Sandwiches  Anna Nagar East
# 12030        CK's Sandwiches        Ramapuram
# 12031        CK's Sandwiches   Sholinganallur
#
#                                                  Cuisine  \
# 0                                            ['Biryani']
# 1      ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2      ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3      ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4      ['Chinese', ' Biryani', ' North Indian', ' Che...
# ...                                                  ...
# ...

# %%
# Confirming all the null records are correct
dataset.isnull().sum()
# Out:
# Name of Restaurant       0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %% [markdown]
# # c. Converting the DataTypes of numerical columns to numeric dataype

# %%
# Checking for text values in the column before converting it to numeric datatype
dataset['Dining Rating'].value_counts()
# Out:
# Dining Rating
# NA     5351
# 3.6     584
# 3.5     553
# 3.7     525
# 3.4     500
# 3.3     463
# 3.8     460
# 3.2     433
# 3.9     379
# 3.1     363
# 2.0     354
# 3.0     302
# 4.0     288
# 2.9     257
# 4.1     221
# 2.8     192
# 4.2     142
# 2.7     138
# 4.3     105
# 2.6      99
# 2.5      71
# 4.4      61
# 2.4      46
# 4.5      36
# 2.3      32
# 2.2      20
# 4.6      17
# 4.7      12
# 2.1      10
# 4.9       7
# 4.8       4
# 1.9       3
# 1.7       2
# 0.3       1
# 1.0       1
# Name: count, dtype: int64

# %%
# Count the frequency of each rating
rating_counts = dataset['Dining Rating'].value_counts()

# Plot a bar chart
plt.figure(figsize=(12,4))
rating_counts.plot(kind='bar')

plt.title('Rating Distribution')
plt.xlabel('Dining Rating')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.9)

plt.show()

# %%
# Using Seaborn (more stylish
plt.figure(figsize=(12,4))
sns.countplot(x='Dining Rating', hue='Dining Rating', data=dataset, palette='viridis', legend=False)

plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()

# %%
# Replacing the text values with '0'

# dataset['Dining Rating'].replace(to_replace=['-','NEW','Opening'], value='0', inplace=True) 
# below give without wrning code use any one code
# dataset.replace({'RATING': {'-': '0', 'NEW': '0', 'Opening': '0'}}, inplace=True)
dataset['Dining Rating'] = dataset['Dining Rating'].replace('NA', '0')

# %%
# Checking for text values in the column before converting it to numeric datatype
dataset['Dining Rating Count'].value_counts()
# Out:
# Dining Rating Count
# 0       5151
# 4        339
# 5        271
# 6        248
# NA       220
#         ...
# 877        1
# 897        1
# 872        1
# 1197       1
# 224        1
# Name: count, Length: 792, dtype: int64

# %%
# Replacing the text values with '0'
dataset['Dining Rating Count'] = dataset['Dining Rating Count'].replace(['NA'], '0')

# %%
# Checking for text values in the column before converting it to numeric datatype
dataset['Delivery Rating'].value_counts()
# Out:
# Delivery Rating
# 0      5351
# 3.6     584
# 3.5     553
# 3.7     525
# 3.4     500
# 3.3     463
# 3.8     460
# 3.2     433
# 3.9     379
# 3.1     363
# 2.0     354
# 3.0     302
# 4.0     288
# 2.9     257
# 4.1     221
# 2.8     192
# 4.2     142
# 2.7     138
# 4.3     105
# 2.6      99
# 2.5      71
# 4.4      61
# 2.4      46
# 4.5      36
# 2.3      32
# 2.2      20
# 4.6      17
# 4.7      12
# 2.1      10
# 4.9       7
# 4.8       4
# 1.9       3
# 1.7       2
# 0.3       1
# 1.0       1
# Name: count, dtype: int64

# %%
# Replacing the text values with '0'
dataset['Delivery Rating'] = dataset['Delivery Rating'].replace(['NA'], '0')

# %%
# Checking for text values in the column before converting it to numeric datatype
dataset['Delivery Rating Count'].value_counts()
# Out:
# Delivery Rating Count
# 0       5870
# 27        34
# 22        30
# 37        30
# 60        30
#         ...
# 6374       1
# 3677       1
# 588        1
# 6125       1
# 1617       1
# Name: count, Length: 2279, dtype: int64

# %%
# Replacing the text values with '0'
dataset['Delivery Rating Count'] = dataset['Delivery Rating Count'].replace(['Not enough Delivery Reviews', 'Does not offer Delivery', 'NA'], '0')

# %%
# Changing Data Type of the numerical columns

dataset['Price for 2'] = dataset['Price for 2'].astype('int64')

dataset['Dining Rating'] = dataset['Dining Rating'].astype('float64') 
dataset['Dining Rating Count'] = dataset['Dining Rating Count'].astype('int64')

dataset['Delivery Rating'] = dataset['Delivery Rating'].astype('float64') 
dataset['Delivery Rating Count'] = dataset['Delivery Rating Count'].astype('int64')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name of Restaurant     12032 non-null  object
#  1   Location               12032 non-null  object
#  2   Cuisine                12032 non-null  object
#  3   Top Dishes             12032 non-null  object
#  4   Price for 2            12032 non-null  int64
#  5   Dining Rating          12032 non-null  float64
#  6   Dining Rating Count    12032 non-null  int64
#  7   Delivery Rating        12032 non-null  float64
#  8   Delivery Rating Count  12032 non-null  int64
#  9   Features               12032 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 940.1+ KB

# %%
# Finding those restaurant whose has 0 Rating or Votes

useless_data = (dataset['Dining Rating'] == 0.0) | (dataset['Delivery Rating'] == 0) | (dataset['Dining Rating Count'] == 0) | (dataset['Delivery Rating Count'] == 0) 
dataset[useless_data]
# Out:
#              Name of Restaurant                        Location  \
# 6            Bai Veetu Kalyanam                        Navallur
# 15                Welcome Hotel                    Purasavakkam
# 18      Wire Room Bar & Kitchen  Phoenix Market City, Velachery
# 23                      BFF 2.0                        RA Puram
# 77     Al Dhareeq Beef Biriyani                     Kodambakkam
# ...                         ...                             ...
# 12027           CK's Sandwiches                           Porur
# 12028           CK's Sandwiches                        Kolathur
# 12029           CK's Sandwiches                 Anna Nagar East
# 12030           CK's Sandwiches                       Ramapuram
# 12031           CK's Sandwiches                  Sholinganallur
#
#                                             Cuisine  \
# 6                                       ['Biryani']
# 15      ['South Indian', ' Desserts', ' Beverages']
# ...

# %%
## Performing Negation of the useless dataset and then storing the correct data back in the raw_df DataFrame 
## This permamnently remove the wrong data from the original dataframe

dataset = dataset[~useless_data]
dataset
# Out:
#                        Name of Restaurant     Location  \
# 0                   Yaa Mohaideen Briyani   Pallavaram
# 1                      Sukkubhai Biriyani      Alandur
# 2                    SS Hyderabad Biryani  Kodambakkam
# 3                                     KFC     Perambur
# 4                           Tasty Kitchen     Perambur
# ...                                   ...          ...
# 11666                         Juice World      Alandur
# 11667                         Juice World   Palavakkam
# 11736  Adyar Vaishnavas Thattu Idly Kadai        Porur
# 11785                   Engineers Kitchen     Ambattur
# 11794                     That Juice Shop   Karapakkam
#
#                                                  Cuisine  \
# 0                                            ['Biryani']
# 1      ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2      ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3      ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# ...

# %% [markdown]
# # f. Working on 'Top Dishes' Column

# %%
# Convert to string
dataset['Top Dishes'] = dataset['Top Dishes'].astype(str)

# %%
# Step 1: Replace known invalid words
dataset['Top Dishes'] = dataset['Top Dishes'].replace(
    ['Invalid', 'invalid', 'None', 'nan', 'NaN', '-', '[]'], np.nan)

# %%
# Step 2: Remove brackets and quotes
dataset['Top Dishes'] = dataset['Top Dishes'].str.replace(r"[\[\]']", '', regex=True)

# %%
# Step 3: Remove leading/trailing spaces
dataset['Top Dishes'] = dataset['Top Dishes'].str.strip()

# Step 4: Remove multiple spaces
dataset['Top Dishes'] = dataset['Top Dishes'].str.replace(r'\s+', ' ', regex=True)

# Step 5: Remove trailing commas
dataset['Top Dishes'] = dataset['Top Dishes'].str.replace(r',\s*$', '', regex=True)

# %%
# Checking the unique values in the column
dataset['Top Dishes'].value_counts()
# Out:
# Top Dishes
# Biryani                                                                                              25
# Chicken Biryani                                                                                      11
# Coffee                                                                                               10
# Pizza, Garlic Bread                                                                                   9
# Sandwich                                                                                              9
#                                                                                                      ..
# Malai Kebab, Fish, Chicken Wings, Brownie, Rose Sharbat, Kulfi, Tandoori Chicken                      1
# Chaat, Panipuri, Pav Bhaji, Paratha, Masala Poori, Bhel Puri, Samosa                                  1
# Mutton Biryani, Mutton Chukka, Omelette, Vanjaram Fry, Kadalai Mittai, Barfi                          1
# ...

# %% [markdown]
# # g. Working on 'Cuisine' Column

# %%
dataset['Cuisine'].value_counts()
# Out:
# Cuisine
# ['South Indian']                                                                                        163
# ['Pizza', ' Fast Food']                                                                                  97
# ['North Indian', ' Chinese']                                                                             89
# ['Fast Food']                                                                                            83
# ['South Indian', ' Chinese']                                                                             73
#                                                                                                        ...
# ['Fast Food', ' Chettinad', ' Chinese', ' Pizza', ' Mughlai', ' Biryani', ' Desserts', ' Beverages']      1
# ['Chinese', ' Momos', ' Desserts', ' Beverages']                                                          1
# ['Fast Food', ' Biryani', ' Chinese']                                                                     1
# ...

# %%
# Convert to string
dataset['Cuisine'] = dataset['Cuisine'].astype(str)

# Step 1: Replace known invalid words
dataset['Cuisine'] = dataset['Cuisine'].replace(
    ['Invalid', 'invalid', 'None', 'nan', 'NaN', '-', '[]'], np.nan)

# Step 2: Remove brackets and quotes
dataset['Cuisine'] = dataset['Cuisine'].str.replace(r"[\[\]']", '', regex=True)

# Step 3: Remove leading/trailing spaces
dataset['Cuisine'] = dataset['Cuisine'].str.strip()

# Step 4: Remove multiple spaces
dataset['Cuisine'] = dataset['Cuisine'].str.replace(r'\s+', ' ', regex=True)

# Step 5: Remove trailing commas
dataset['Cuisine'] = dataset['Cuisine'].str.replace(r',\s*$', '', regex=True)

# %%
dataset['Cuisine'].value_counts()
# Out:
# Cuisine
# South Indian                                                                   163
# Pizza, Fast Food                                                                97
# North Indian, Chinese                                                           89
# Fast Food                                                                       83
# South Indian, Chinese                                                           73
#                                                                               ...
# Fast Food, Chettinad, Chinese, Pizza, Mughlai, Biryani, Desserts, Beverages      1
# Chinese, Momos, Desserts, Beverages                                              1
# Fast Food, Biryani, Chinese                                                      1
# Chettinad, South Indian, Chinese, Beverages, Arabian, North Indian               1
# Juices, Beverages, Sandwich, Fast Food                                           1
# Name: count, Length: 1336, dtype: int64

# %% [markdown]
# # h. Working on 'Features' Column

# %%
dataset['Features'].value_counts()
# Out:
# Features
# Home Delivery, Indoor Seating                                                                          1375
# Breakfast, Home Delivery, Indoor Seating                                                                257
# Home Delivery, Free Parking, Indoor Seating                                                             211
# Home Delivery, Indoor Seating, Desserts and Bakes                                                       189
# Breakfast, Home Delivery, Vegetarian Only, Indoor Seating                                               144
#                                                                                                        ...
# Home Delivery, Valet Parking Available, Live Music, Smoking Area, Outdoor Seating, Wifi                   1
# Home Delivery, Free Parking, Indoor Seating, Table reservation required                                   1
# Home Delivery, Vegetarian Only, Valet Parking Available, Buffet, Indoor Seating, Catering Available       1
# ...

# %%
# Convert to string
dataset['Features'] = dataset['Features'].astype(str)

# Step 1: Replace known invalid words
dataset['Features'] = dataset['Features'].replace(
    ['Invalid', 'invalid', 'None', 'nan', 'NaN', '-', '[]'], np.nan)

# Step 2: Remove brackets and quotes
dataset['Features'] = dataset['Features'].str.replace(r"[\[\]']", '', regex=True)

# Step 3: Remove leading/trailing spaces
dataset['Features'] = dataset['Features'].str.strip()

# Step 4: Remove multiple spaces
dataset['Features'] = dataset['Features'].str.replace(r'\s+', ' ', regex=True)

# Step 5: Remove trailing commas
dataset['Features'] = dataset['Features'].str.replace(r',\s*$', '', regex=True)

# %%
dataset['Features'].value_counts()
# Out:
# Features
# Home Delivery, Indoor Seating                                                                          1375
# Breakfast, Home Delivery, Indoor Seating                                                                257
# Home Delivery, Free Parking, Indoor Seating                                                             211
# Home Delivery, Indoor Seating, Desserts and Bakes                                                       189
# Breakfast, Home Delivery, Vegetarian Only, Indoor Seating                                               144
#                                                                                                        ...
# Home Delivery, Valet Parking Available, Live Music, Smoking Area, Outdoor Seating, Wifi                   1
# Home Delivery, Free Parking, Indoor Seating, Table reservation required                                   1
# Home Delivery, Vegetarian Only, Valet Parking Available, Buffet, Indoor Seating, Catering Available       1
# ...

# %% [markdown]
# # f.Removing Duplicate records

# %%
# Finding all the duplicate rows

dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name of Restaurant, Location, Cuisine, Top Dishes, Price for 2, Dining Rating, Dining Rating Count, Delivery Rating, Delivery Rating Count, Features]
# Index: []

# %%
# Dropping all the duplicate rows

dataset = dataset.drop_duplicates()
dataset
# Out:
#                        Name of Restaurant     Location  \
# 0                   Yaa Mohaideen Briyani   Pallavaram
# 1                      Sukkubhai Biriyani      Alandur
# 2                    SS Hyderabad Biryani  Kodambakkam
# 3                                     KFC     Perambur
# 4                           Tasty Kitchen     Perambur
# ...                                   ...          ...
# 11666                         Juice World      Alandur
# 11667                         Juice World   Palavakkam
# 11736  Adyar Vaishnavas Thattu Idly Kadai        Porur
# 11785                   Engineers Kitchen     Ambattur
# 11794                     That Juice Shop   Karapakkam
#
#                                                  Cuisine  \
# 0                                                Biryani
# 1      Biryani, North Indian, Mughlai, Desserts, Beve...
# 2                Biryani, North Indian, Chinese, Arabian
# 3              Burger, Fast Food, Finger Food, Beverages
# ...

# %% [markdown]
# # 4.Copying the cleaned data into a new DataFrame

# %%
zomato_df = dataset.copy()
zomato_df.columns
# Out:
# Index(['Name of Restaurant', 'Location', 'Cuisine', 'Top Dishes',
#        'Price for 2', 'Dining Rating', 'Dining Rating Count',
#        'Delivery Rating', 'Delivery Rating Count', 'Features'],
#       dtype='object')

# %% [markdown]
# # 5. Performing Exploratory Data Analysis

# %% [markdown]
# # Q1) How many restaurants are in Chennai for loction wise?

# %%
#!pip install kaleido
import plotly.express as px
# zomato_df['CUSINE TYPE'] = zomato_df['CUSINE TYPE'].astype(str)
# zomato_df['CUSINE TYPE'] = zomato_df['CUSINE TYPE'].str.strip()
# zomato_df = zomato_df[zomato_df['CUSINE TYPE'].str.lower() != 'nan']
fig = px.histogram(zomato_df, x='Location', color='Location', title= 'No. of Restaurants by Area Wise')
fig.size(12,4)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[194], line 7
#       3 # zomato_df['CUSINE TYPE'] = zomato_df['CUSINE TYPE'].astype(str)
#       4 # zomato_df['CUSINE TYPE'] = zomato_df['CUSINE TYPE'].str.strip()
#       5 # zomato_df = zomato_df[zomato_df['CUSINE TYPE'].str.lower() != 'nan']
#       6 fig = px.histogram(zomato_df, x='Location', color='Location', title= 'No. of Restaurants by Area Wise')
# ----> 7 fig.size(12,4)
#       8 fig.show()
#
# AttributeError: 'Figure' object has no attribute 'size'

# %% [markdown]
# # Q2) What are the percentage of restaurants by Rating Type in Mumbai?

# %%
rating_type_df = zomato_df['Dining Rating'].value_counts().reset_index()
# rating_type_df = zomato_df['RATING_TYPE'].value_counts()
rating_type_df.rename(columns={'index':'Dining Rating', 'count':'COUNT OF RESTAURANTS'}, inplace=True) 
rating_type_df
# Out:
#     Dining Rating  COUNT OF RESTAURANTS
# 0             3.7                   387
# 1             3.6                   377
# 2             3.5                   359
# 3             3.8                   334
# 4             3.4                   320
# 5             3.9                   301
# 6             3.3                   293
# 7             3.2                   260
# 8             3.1                   236
# 9             4.0                   222
# 10            3.0                   191
# 11            4.1                   166
# 12            2.9                   160
# 13            2.8                   120
# 14            2.0                   109
# 15            4.2                   105
# 16            4.3                    87
# 17            2.7                    77
# 18            2.6                    56
# 19            2.5                    44
# 20            4.4                    39
# 21            2.4                    26
# ...

# %%
fig = px.pie(rating_type_df, names='Dining Rating', values='COUNT OF RESTAURANTS', color='Dining Rating',
             title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside', textinfo='percent+label')

fig.show()

# %% [markdown]
# # Q3) Which are the Top 10 highest rated Seafood Restaurant in Mumbai?

# %%
zomato_df
# Out:
#                        Name of Restaurant     Location  \
# 0                   Yaa Mohaideen Briyani   Pallavaram
# 1                      Sukkubhai Biriyani      Alandur
# 2                    SS Hyderabad Biryani  Kodambakkam
# 3                                     KFC     Perambur
# 4                           Tasty Kitchen     Perambur
# ...                                   ...          ...
# 11666                         Juice World      Alandur
# 11667                         Juice World   Palavakkam
# 11736  Adyar Vaishnavas Thattu Idly Kadai        Porur
# 11785                   Engineers Kitchen     Ambattur
# 11794                     That Juice Shop   Karapakkam
#
#                                                  Cuisine  \
# 0                                                Biryani
# 1      Biryani, North Indian, Mughlai, Desserts, Beve...
# 2                Biryani, North Indian, Chinese, Arabian
# 3              Burger, Fast Food, Finger Food, Beverages
# ...

# %%
z = zomato_df['Cuisine'].str.contains('Seafood')
z1= zomato_df[z]
z1
# Out:
#              Name of Restaurant    Location  \
# 14              Hotel Paramount     Kilpauk
# 17                       Abid's     Chetpet
# 25    Salem RR Briyani Unavagam   Velachery
# 49                  Sea Emperor  Madipakkam
# 53               Copper Kitchen  Saligramam
# ...                         ...         ...
# 9617                   Anjappar  Palavakkam
# 9618                   Anjappar      Parrys
# 9619                   Anjappar  Triplicane
# 9620                   Anjappar    GST Road
# 9622                   Anjappar    T. Nagar
#
#                                                 Cuisine  \
# 14    North Indian, Chinese, Seafood, South Indian, ...
# 17    Seafood, Biryani, Hyderabadi, Arabian, North I...
# 25    Biryani, Chinese, North Indian, Seafood, Bever...
# 49              Chinese, Arabian, North Indian, Seafood
# 53            North Indian, Chinese, Chettinad, Seafood
# ...                                                 ...
# ...

# %%
seafood_df = zomato_df[zomato_df['Cuisine'].str.contains('Seafood')] 
seafood_df.sort_values(by='Dining Rating',ascending=False).head(10)
# Out:
#                      Name of Restaurant         Location  \
# 195                          The Marina     Nungambakkam
# 214   Sera - The Tapas Bar & Restaurant      Gopalapuram
# 315                             Layalee    Ekkaduthangal
# 96                        Urban Spatula  Anna Nagar West
# 14                      Hotel Paramount          Kilpauk
# 133                          Azzuri Bay            Adyar
# 9027                     Copper Kitchen      Kotturpuram
# 9026                     Copper Kitchen            Porur
# 237                         The Cascade     Nungambakkam
# 153                         The Bayleaf      Gopalapuram
#
#                                                 Cuisine  \
# 195                      Seafood, North Indian, Chinese
# 214          Finger Food, Seafood, Italian, Continental
# 315   Arabian, BBQ, Seafood, Chinese, Continental, Thai
# 96    Continental, Seafood, Biryani, Italian, North ...
# ...

# %% [markdown]
# # Q4) Which is the best Asian food in Chennai?

# %%
foodtruck_df=zomato_df[zomato_df['Cuisine'].str.contains('Asian')]
foodtruck_df.sort_values(by='Dining Rating',ascending=False)
# Out:
#                   Name of Restaurant                        Location  \
# 382                         Wok Monk                 Anna Nagar West
# 102                   Mainland China  Phoenix Market City, Velachery
# 243   Asia Kitchen by Mainland China  The Spring Hotel, Nungambakkam
# 110                     VB Signature                    Nungambakkam
# 207           Va Pho - Asian Canteen                     Gopalapuram
# ...                              ...                             ...
# 9513                   Wangs Kitchen                           Adyar
# 9528                   Wangs Kitchen                           Porur
# 9522                   Wangs Kitchen                       Velachery
# 9515                   Wangs Kitchen                         Kilpauk
# 9529                   Wangs Kitchen                        Nandanam
#
#                                                 Cuisine  \
# 382                      Asian, Chinese, Middle Eastern
# ...

# %% [markdown]
# # Q5a) Which places have the highest rated restaurant for Location wise in Chennai?

# %%
# Assuming restaurants having rating above 4.5
highest_rated_df = zomato_df.loc[zomato_df.groupby('Location')['Dining Rating'].idxmax()]
highest_rated_df
# Out:
#            Name of Restaurant       Location  \
# 1270           Thug Life Cafe  Abhiramapuram
# 310                Hotel Mass     Adambakkam
# 219     Prems Graama Bhojanam          Adyar
# 10063     Cold Stone Creamery        Akkarai
# 1          Sukkubhai Biriyani        Alandur
# ...                       ...            ...
# 739                 Cafe Litt         Vepery
# 8886   Dindigul Thalappakatti   Vettuvankeni
# 2248          RR Anbu Briyani  Virugambakkam
# 113            Madras2Chennai   Washermenpet
# 155         The Sandwich Shop  West Mambalam
#
#                                                  Cuisine  \
# 1270               Fast Food, Pizza, Sandwich, Beverages
# 310                              Biryani, Fast Food, BBQ
# 219                                         South Indian
# 10063                                Desserts, Ice Cream
# 1      Biryani, North Indian, Mughlai, Desserts, Beve...
# ...                                                  ...
# ...

# %% [markdown]
# # 5b) restaurants having rating above 4.5

# %%
# Assuming restaurants having rating above 4.5
highest_rated = zomato_df[zomato_df['Dining Rating'] >= 4.5] 
highest_rated
# Out:
#                       Name of Restaurant                             Location  \
# 24                        Eating Circles                             Alwarpet
# 37                          Shree Mithai                              Chetpet
# 50                           Andhikkadai                            Velachery
# 57                        Brownie Heaven                           Royapettah
# 59                                 Mezze                             Alwarpet
# 62    Amadora Gourmet Ice Cream & Sorbet                         Nungambakkam
# 67                         Pumpkin Tales                             Alwarpet
# 68          Sandy's Chocolate Laboratory                         Nungambakkam
# 70                          Little Italy                         Besant Nagar
# 75                       Fusilli Reasons                              Kilpauk
# 78                 Shri Rajasthani Dhaba                      Anna Nagar West
# ...

# %% [markdown]
# # 5c) restaurants having Highest rating

# %%
# Assuming restaurants having highest rating 
highest_rating = zomato_df['Dining Rating'].max()
highest_rate = zomato_df[zomato_df['Dining Rating'] == highest_rating]
highest_rate
# Out:
#         Name of Restaurant                      Location  \
# 57          Brownie Heaven                    Royapettah
# 105                Bhangra  Mayajaal Multiplex, Kanathur
# 155      The Sandwich Shop                 West Mambalam
# 184   Gossip Fusion Bistro                      Kanathur
# 192           Kabab Corner                        Egmore
# 219  Prems Graama Bhojanam                         Adyar
# 320           Bombay Kulfi                         Adyar
#
#                                                Cuisine  \
# 57                         Bakery, Desserts, Beverages
# 105                                       North Indian
# 155                     Sandwich, Fast Food, Beverages
# 184  Italian, Continental, Burger, Sandwich, Wraps,...
# 192                              Kebab, Rolls, Mughlai
# 219                                       South Indian
# 320                                          Ice Cream
#
# ...

# %% [markdown]
# # Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Mumbai?

# %%
highest_rated_price_df = highest_rated_df.groupby(by=['Location', 'Cuisine'])['Price for 2'].mean().reset_index() 
highest_rated_price_df.head()
# Out:
#         Location                                            Cuisine  \
# 0  Abhiramapuram              Fast Food, Pizza, Sandwich, Beverages
# 1     Adambakkam                            Biryani, Fast Food, BBQ
# 2          Adyar                                       South Indian
# 3        Akkarai                                Desserts, Ice Cream
# 4        Alandur  Biryani, North Indian, Mughlai, Desserts, Beve...
#
#    Price for 2
# 0        200.0
# 1        300.0
# 2        500.0
# 3        500.0
# 4       1000.0

# %%
fig = px.scatter(highest_rated_price_df, x="Location", y="Price for 2", color="Cuisine", symbol="Cuisine",
title=' Avg Price Distibution of High rated restaurant for each Cuisine Type').update_traces(marker_size=10)

fig.show()

# %% [markdown]
# # Q7) Which areas have a large number of Chinese Restaurant Market?

# %%
chinese_df = zomato_df[zomato_df['Cuisine'].str.contains('Chinese')] 
chinese_df
# Out:
#                        Name of Restaurant         Location  \
# 2                    SS Hyderabad Biryani      Kodambakkam
# 4                           Tasty Kitchen         Perambur
# 5                              Dine N Fun       Medavakkam
# 8                       Savoury Sea Shell  Anna Nagar East
# 9                Sangeetha Veg Restaurant         T. Nagar
# ...                                   ...              ...
# 11382                         Texas Treat         Selaiyur
# 11544                  Anandhi Idly Kadai       Medavakkam
# 11545                  Anandhi Idly Kadai         Selaiyur
# 11736  Adyar Vaishnavas Thattu Idly Kadai            Porur
# 11785                   Engineers Kitchen         Ambattur
#
#                                                  Cuisine  \
# 2                Biryani, North Indian, Chinese, Arabian
# 4      Chinese, Biryani, North Indian, Chettinad, Ara...
# 5                    South Indian, North Indian, Chinese
# ...

# %%
# Group, aggregate, rename
chinese_rest_df = (
    chinese_df
    .groupby('Location')
    .agg({'Name of Restaurant': 'count', 'Price for 2': 'mean'})
    .rename(columns={
        'Name of Restaurant': 'COUNT OF RESTAURANTS',
        'Price for 2': 'AVERAGE PRICE'
    })
)

# Sort and take top 25
chinese_rest_df = chinese_rest_df.sort_values(
    'COUNT OF RESTAURANTS',
    ascending=False
).head(25)

# FIX: Reset index so REGION becomes a column
chinese_rest_df = chinese_rest_df.reset_index()
chinese_rest_df
# Out:
#            Location  COUNT OF RESTAURANTS  AVERAGE PRICE
# 0             Porur                    58     490.517241
# 1   Anna Nagar East                    57     638.596491
# 2          Ambattur                    52     415.384615
# 3          T. Nagar                    47     501.063830
# 4         Velachery                    46     576.086957
# 5          Kolathur                    45     448.888889
# 6          Perambur                    45     476.666667
# 7         Ramapuram                    43     445.348837
# 8        Medavakkam                    42     530.952381
# 9         Mogappair                    41     529.268293
# 10     Thuraipakkam                    41     578.048780
# 11        Perungudi                    41     507.317073
# 12         Tambaram                    39     510.256410
# 13  Anna Nagar West                    38     506.578947
# 14         GST Road                    36     472.222222
# ...

# %%
# Plot
fig = px.bar(
    chinese_rest_df,
    x='Location',
    y='COUNT OF RESTAURANTS',
    color='AVERAGE PRICE',
    title='No. of Chinese Restaurants by Places'
)

fig.show()

# %% [markdown]
# # Q8) Is there a relation between Price and Rating by each Cuisine Type?

# %%
price_rating_df = zomato_df.groupby(['Cuisine', 'Dining Rating'])['Price for 2'].mean().reset_index() 
price_rating_df
# Out:
#                                                 Cuisine  Dining Rating  \
# 0                                 American, Continental            4.1
# 1              American, Continental, European, Italian            3.9
# 2     American, Continental, Italian, North Indian, ...            4.1
# 3                                   American, Fast Food            2.7
# 4                                   American, Fast Food            3.9
# ...                                                 ...            ...
# 2881                                     Tibetan, Momos            3.1
# 2882                                     Tibetan, Momos            3.4
# 2883                                     Tibetan, Momos            3.5
# 2884                                     Tibetan, Momos            3.6
# 2885                                     Turkish, Kebab            4.3
#
#       Price for 2
# 0          1600.0
# 1           700.0
# 2           800.0
# 3           300.0
# ...

# %%
fig = px.line(price_rating_df, y="Price for 2", x="Dining Rating",color='Cuisine')
fig.show()

# %% [markdown]
# # Q9) Is there a relation between Region and Price?

# %%
region_price_df = zomato_df.groupby(['Location'])['Price for 2'].mean().reset_index() 
region_price_df
# Out:
#           Location  Price for 2
# 0    Abhiramapuram   200.000000
# 1       Adambakkam   327.631579
# 2            Adyar   528.865979
# 3          Akkarai   575.000000
# 4          Alandur   442.857143
# ..             ...          ...
# 156         Vepery   350.000000
# 157   Vettuvankeni   475.000000
# 158  Virugambakkam   425.000000
# 159   Washermenpet   380.555556
# 160  West Mambalam   294.230769
#
# [161 rows x 2 columns]

# %%
fig = px.scatter(region_price_df, x="Location", y="Price for 2").update_traces(marker_size=8) 
fig.show()

# %% [markdown]
# # Q10 a) Find the list of Affordable Restaurants?

# %%
"""
The criteria for Affordable Restaurants would be:-
1) Low Price 
2) High Rated
First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our dataframe.
Let me explain:-The most expensive restaurant has an average meal cost= 6000.
We will try to stay economical and only pick the restaurants that are 1/4th of 6000.
"""
# Out:
# '\nThe criteria for Affordable Restaurants would be:-\n1) Low Price \n2) High Rated\nFirst step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our dataframe.\nLet me explain:-The most expensive restaurant has an average meal cost= 6000.\nWe will try to stay economical and only pick the restaurants that are 1/4th of 6000.\n'

# %%
max_price = zomato_df['Price for 2'].max() 
one_fourth_price = max_price/4
one_fourth_price
# Out:
# 750.0

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauran

aff_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location',]]
aff_rest_df = aff_rest_df[aff_rest_df['Price for 2'] <= one_fourth_price] 
aff_rest_df.sort_values(by='Price for 2', inplace=True)
aff_rest_df
# Out:
#                       Name of Restaurant  Price for 2  \
# 108                         Rayar's Mess          100
# 1518                      Lassi Junction          100
# 4564   Iniyavai Delicious Veg Restaurant          100
# 5862                          A.P.S Chat          100
# 2151                            Cane 4 U          100
# ...                                  ...          ...
# 8817                   Savoury Sea Shell          750
# 10074                    Long Live Pizza          750
# 2296                    Ponnis Grand Inn          750
# 2102                   Al Arz Restaurant          750
# 9626                          Kaaraikudi          750
#
#                                    Cuisine  \
# 108                           South Indian
# 1518                  Beverages, Ice Cream
# 4564                          South Indian
# 5862                           Street Food
# 2151                             Beverages
# ...                                    ...
# ...

# %%
# Finding the highest rated list of restaurants
highrate_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location','Dining Rating']]
highrate_rest_df = highrate_rest_df[highrate_rest_df['Dining Rating'] >= 4.5] 
highrate_rest_df.sort_values(by='Price for 2', inplace=True)
highrate_rest_df
# Out:
#                       Name of Restaurant  Price for 2  \
# 108                         Rayar's Mess          100
# 178                  Royal Sandwich Shop          150
# 9541                        Bombay Kulfi          200
# 320                         Bombay Kulfi          200
# 50                           Andhikkadai          200
# 24                        Eating Circles          250
# 37                          Shree Mithai          300
# 270                                   ID          300
# 155                    The Sandwich Shop          300
# 209                          Cream Stone          350
# 9367                         Cream Stone          350
# 92             Fruit Shop On Greams Road          350
# 57                        Brownie Heaven          350
# 163     Momo Sa-Khang by Kailash Kitchen          350
# 255                         Krispy Kreme          400
# 471   Shmoozie's Hand-Crafted Ice Creams          400
# ...

# %%
# Now, we'll merge the aff_rest_df with highrate_rest_df to obtain the intersection i.e the list of Affordable Restaurants !!

# %%
highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['Name of Restaurant', 'Location'])
highrate_aff_df = highrate_aff_df[['Name of Restaurant', 'Price for 2_x', 'Cuisine_x', 'Location','Dining Rating']]
highrate_aff_df.rename(columns={'Name of Restaurant':'Name of Restaurant', 'Price for 2_x':'Price for 2', 'Cuisine_x':'Cuisine',
                                'Location':'Location'},inplace=True)

# %%
# Affordable Restaurants with low price and high rating

highrate_aff_df
# Out:
#                     Name of Restaurant  Price for 2  \
# 0                         Rayar's Mess          100
# 1                  Royal Sandwich Shop          150
# 2                  Royal Sandwich Shop          150
# 3                  Royal Sandwich Shop          150
# 4                         Bombay Kulfi          200
# 5                         Bombay Kulfi          200
# 6                          Andhikkadai          200
# 7                       Eating Circles          250
# 8                         Shree Mithai          300
# 9                    The Sandwich Shop          300
# 10                                  ID          300
# 11                         Cream Stone          350
# 12           Fruit Shop On Greams Road          350
# 13                         Cream Stone          350
# 14                      Brownie Heaven          350
# 15    Momo Sa-Khang by Kailash Kitchen          350
# 16                          Ratna Cafe          400
# ...

# %% [markdown]
# # Q10 b) Find the list of most Reliable Restaurants?

# %%
"""
The criteria for most Reliable Restaurants would be:-
1) Low Price 2) High Rated 3) Large No. of Votes
First step will be to find the restaurants with Votes greater than Mean of Votes
"""
# Out:
# '\nThe criteria for most Reliable Restaurants would be:-\n1) Low Price 2) High Rated 3) Large No. of Votes\nFirst step will be to find the restaurants with Votes greater than Mean of Votes\n'

# %%
mean_votes = zomato_df['Dining Rating Count'].mean() 
mean_votes
# Out:
# 169.73469387755102

# %%
# Finding list of restaurants that have Votes greater than and equal to Mean of Vote

mean_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location','Dining Rating Count']]
mean_rest_df = mean_rest_df[mean_rest_df['Dining Rating Count'] > mean_votes] 
mean_rest_df.sort_values(by='Dining Rating Count', inplace=True)
mean_rest_df
# Out:
#                      Name of Restaurant  Price for 2  \
# 1127                Kalpana Andhra Mess          350
# 1070                   Grill & Barbeque          400
# 949                            Kebab It          500
# 769   The London Shakes & Chaat Chatore          500
# 651                        Nizam Palace          800
# ...                                 ...          ...
# 9040                          Palmshore         1000
# 9038                          Palmshore         1000
# 9026                     Copper Kitchen         1000
# 9030                   Paradise Biryani          800
# 74                               Onesta          600
#
#                                                 Cuisine  \
# 1127                           Andhra, Chinese, Biryani
# 1070                     Arabian, Chinese, North Indian
# 949                        Kebab, Chinese, North Indian
# 769               Cafe, Street Food, Italian, Beverages
# ...

# %% [markdown]
# """
# These are the most reliable, highest rated and affordable restaurants:-
# We obtain this dataframe by simply taking the intersection of highrate_aff_df & mean_rest_df
# This dataframe obtained below shows the restaurants whose:
# Cost is below 1250   .
# Rating is above 4.5
# Votes are above 177
# """

# %%
# Plot
fig = px.bar(
    reliable_rest_df,
    x='Location',
    y='Price for 2',
    color='Price for 2',
    title='Relaiable Restaurants'
)

fig.show()

# %%
#zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location','Dining Rating Count']]
reliable_rest_df = pd.merge(mean_rest_df, highrate_aff_df, how='inner', on=['Name of Restaurant', 'Location'])
reliable_rest_df = reliable_rest_df[['Name of Restaurant', 'Price for 2_x', 'Cuisine_x', 'Location', 'Dining Rating','Dining Rating Count']]
reliable_rest_df.rename(columns={'Name of Restaurant':'NAME', 'Price for 2_x':'PRICE', 'Cuisine_x':'Cuisine','Location':'Location'},inplace=True)
#reliable_rest_df

# %%
reliable_rest_df.columns
# Out:
# Index(['NAME', 'PRICE', 'Cuisine', 'Location', 'Dining Rating',
#        'Dining Rating Count'],
#       dtype='object')

# %%
# Plot
fig = px.bar(
    reliable_rest_df,
    x='Location',
    y='PRICE',
    color='PRICE',
    title='Relaiable Restaurants'
)
fig = px.bar(
    reliable_rest_df,
    x='Location',
    y='PRICE',
    color='PRICE',
    title='Relaiable Restaurants'
)

fig.show()
